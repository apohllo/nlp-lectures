# %% [markdown]
# # Duże modele językowe (LLMs)
#
# <br/>
#
# ## dr inż. Aleksander Smywiński-Pohl
#
# ## apohllo@agh.edu.pl
#
# ## http://apohllo.pl/dydaktyka/nlp
#
# ## konsultacje: środa 17-18

# %% [markdown]
# * DeepSpeed
# * Petals
# * GPT-3 - 175 miliardów
# * Gopher - 280 miliardów
# * Chinchilla - 60 miliardów
# * LaMDA - 137 miliardów
# * Bloom - 176 miliardów, 46 języków naturalnych, 13 języków programowania
# * Megatron-Turing NLG - 530 miliardów
# * Chinese language model
# * warianty GPT WebGPT, InstructGPT, ChatGPT

# %% [markdown]
# # Megatron
#
# &nbsp;
#
# <center>
#     <img src="img/megatron.png" />
#     </center>
#
# <small>
#     https://developer.nvidia.com/blog/using-deepspeed-and-megatron-to-train-megatron-turing-nlg-530b-the-worlds-largest-and-most-powerful-generative-language-model/
#     </small>

# %% [markdown]
# # DeepSpeed
#
# 3D parallelism
#
# * data parallelism
# * model parallelism
# * pipeline parallelism

# %% [markdown]
# # Data parallelism w DeepSpeed
#
# &nbsp;
#
# <center>
#     <img src="img/parallelism-zero.png" />
#     </center>
#
# <small>
#     https://huggingface.co/docs/transformers/v4.17.0/en/parallelism
#     </small>

# %% [markdown]
# # Pipeline parallelism w DeepSpeed
#
# &nbsp;
#
# <center>
#     <img src="img/parallelism-gpipe.png" />
#     </center>
#
# <small>
#     https://huggingface.co/docs/transformers/v4.17.0/en/parallelism
#     </small>

# %% [markdown]
# # 3D parallelism
#
# &nbsp;
#
# <center>
#     <img src="img/parallelism-3d.png" />
#     </center>
#
# <small>
#     https://huggingface.co/docs/transformers/v4.17.0/en/parallelism
#     </small>

# %% [markdown]
# # Gopher (DeepMind)
#
# * 12.2021
# * Gopher: 280 miliardów parametrów
# * 3 artykuły:
#   * Scaling Language Models: Methods, Analysis & Insights from Training Gopher
#   * Ethical and social risks of harm from Language Models
#   * Improving language models by retrieving from trillions of tokens

# %% [markdown]
# # MMLU benchmark
#
# &nbsp;
#
# <center>
#     <img src="img/gopher.svg" />
#     </center>
#
# <small>
#     https://www.deepmind.com/blog/language-modelling-at-scale-gopher-ethical-considerations-and-retrieval
#     </small>

# %% [markdown]
# # Dialog
#
# &nbsp;
#
# <center>
#     <img src="img/gopher-dialog.svg" />
#     </center>
#
#
# <small>
#     https://www.deepmind.com/blog/language-modelling-at-scale-gopher-ethical-considerations-and-retrieval
#     </small>

# %% [markdown]
# # Błędy Gophera
#
# &nbsp;
#
# <center>
#     <img src="img/gopher-failures.svg" />
#     </center>
#
#
# <small>
#     https://www.deepmind.com/blog/language-modelling-at-scale-gopher-ethical-considerations-and-retrieval
#     </small>

# %% [markdown]
# * US Open -> Emma Raducanu
# * South America -> French Guiana
# * e^{\pi i} = -1

# %% [markdown]
# # Gopher rozmiary
#
# &nbsp;
#
# ![image.png](attachment:dec392da-d300-4760-9cbe-3aeefdd4ac95.png)
#
# <small>
